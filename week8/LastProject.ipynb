# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

chromedriver = 'C:/dev_python/Webdriver/chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://lms.sungshin.ac.kr/ilos/main/member/login_form.acl')

#ID
elem = driver.find_element_by_name("loginId")
elem.clear()
elem.send_keys("20201003")

#PW
elem = driver.find_element_by_name("loginPwd")
elem.send_keys("4033414")
elem.send_keys(Keys.RETURN)

time.sleep(3)

#마이페이지 클릭
button = driver.find_element_by_id("user_photo")
button.click()

#수강과목 클릭
button_1 = driver.find_element_by_id("menu_mp_register")
button_1.click()

loop, count = True,0

while loop and count <10:
    try:
        #이전학기 더보기
        button_2 = driver.find_element_by_id("onceLecture")
        button_2.click()

        #수강과목 리스트(2020-1학기)
        subjects = driver.find_element_by_css_selector("#lecture_list")
        print(subjects.text)
    except:
        loop = False
# Out:
# 2021-1학기 정규과목
# 고급C++프로그래밍(004)
# 김설현
# 수/1-3
# 독일어(001)
# 김진숙
# 금/4-6
# 자료구조(001)
# 장재경
# 화/7-9
# 자바프로그래밍(009)
# 이윤경
# 월/4-6
# 전공별 진로 탐색(041)
# 이정은
#   컴퓨터구조(001)
# 김준철
# 수/4-6
# 컴퓨터시스템관리(002)
# 김종완
# 화/1-3
# 2020-2학기 정규과목
# C++프로그래밍(010)
# 심광섭
# 목/7-9(010)
# 기초 회계의 이해(001)
# 이석영
# (001)
# 미적분과 벡터해석 기초(002)
# 황정연
# 금/4-6(002)
# 소프트웨어융합기술개론(001)
# 이일구
# 월/7-9(001)
# 음악은 왜 치료적인가(001)
# 강경선
# (001)
# 이산수학(001)
# 오장민
# 화/4-6(001)
# 창조적 사고와 글쓰기(021)
# 장영미
# 금/1-3(021)
# 2020-1학기 정규과목
# IT개론(002)
# 이재원
# 화/4-6(002)
# 기초 통계학(003)
# 권윤기
# 수/4-6(003)
# 비판적 사고와 토론(010)
# 김종규
# 수/1-3(010)
# 세계의 명화와 사상(001)
# 임상빈
# 월/1-3(001)
# 웹프로그래밍기초(005)
# 서유현
# 목/10-12(005)
# 전공별 진로 탐색(019)
# 이정은
# (019)
# 파이썬프로그래밍(004)
# 윤상덕
# 화/7-9(004)
# 비정규과목
# 2021-1학기 러닝스터디(01)
# 한아름
# 2021.04.12 ~ 2021.05.14
# 2021년도 재학생 온라인 인권 및 젠더폭력예방 교육(11)
# 박현미
# 2021.04.01 ~ 2021.12.31
# [학생] 연구실 및 실험실습실 사용자 안전교육 정기2반(01)
# 전길용
# 2021.03.10 ~ 2021.06.29
# 2020-1 성신스터디그룹(1)
# DAVAASUREN BOLOR
# 2020.04.14 ~ 2020.07.03
# 2020-2 러닝스터디(1)
# DAVAASUREN BOLOR
# 2020.09.01 ~ 2020.12.31
# 2020년도 신입생 온라인 인권 및 젠더폭력예방 교육(2시간)(01)
# 박현미
# 2020.03.09 ~ 2020.04.03
# 2020년도 온라인 장애 인식개선 교육(05)
# 김경내
# 2020.12.02 ~ 2020.12.31
# 내 마음의 쉼표(마음챙김 명상 및 이완 프로그램)(05)
# 조아라
# 2020.05.20 ~ 2020.06.30
# 내 마음의 쉼표(온라인 마음챙김 명상 및 이완 프로그램)(05)
# 정은지
# 2020.11.23 ~ 2021.01.31
# 신입생 자아성장 특강 “인싸? 아싸? No. 그럴싸한 대학 생활”(01)
# 변지애
# 2020.05.06 ~ 2020.06.30
# 온라인 자살예방교육(05)
# 조아라
# 2020.05.20 ~ 2020.06.30
# 응용암호 - 암호는 어떻게 활용되는가?(01)
# 황정연
# 2020.08.17 ~ 2020.09.13
