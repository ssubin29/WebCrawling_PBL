# %%
import requests
from bs4 import BeautifulSoup
a=['https://finance.naver.com/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW','https://finance.naver.com/marketindex/exchangeDetail.nhn?marketindexCd=FX_EURKRW']

for i in a:
    res = requests.get(i)
 
soup = BeautifulSoup(res.content, 'html.parser')


data = soup.select("#content > div.spot > div.today > p.no_today")
for item in data:
   print (item.get_text())
# Out:
# 1,352.44
#
#
# 원

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(10):
    res = requests.get('https://finance.naver.com/marketindex/exchangeDailyQuote.nhn?marketindexCd=FX_USDKRW&page=' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('table.tbl_exchange.today tbody tr')
    for item in data:
        print (item.get_text().strip())
# Out:
# 2021.05.07
# 1,120.50
#   3.50
# 1,140.10
# 1,100.90
# 1,131.40
# 1,109.60
#
#
# 		N/A
#
#
#
#
#
#
# 		1,109.00
# 2021.05.06
# 1,124.00
#   2.00
# 1,143.67
# 1,104.33
# 1,135.00
# 1,113.00
#
#
# 		N/A
#
#
#
#
#
#
# 		1,112.39
# 2021.05.04
# 1,126.00
#  3.00
# 1,145.70
# 1,106.30
# 1,137.00
# 1,115.00
#
#
# 		N/A
#
#
#
#
#
#
# 		1,114.39
# 2021.05.03
# 1,123.00
#  5.50
# 1,142.65
# 1,103.35
# 1,134.00
# 1,112.00
#
#
# 		N/A
#
#
#
#
#
#
# 		1,111.39
# 2021.04.30
# 1,117.50
#  9.00
# 1,137.05
# 1,097.95
# 1,128.40
# 1,106.60
#
#
# 		N/A
#
#
#
#
#
#
# 		1,106.00
# 2021.04.29
# 1,108.50
#   5.50
# 1,127.89
# 1,089.11
# 1,119.30
# 1,097.70
#
#
# 		N/A
#
#
#
#
#
#
# 		1,097.10
# 2021.04.28
# 1,114.00
#  2.00
# 1,133.49
# 1,094.51
# 1,124.90
# 1,103.10
#
#
# 		N/A
#
#
#
#
#
#
# 		1,102.50
# 2021.04.27
# 1,112.00
#  1.00
# 1,131.46
# 1,092.54
# 1,122.80
# 1,101.20
#
#
# 		N/A
#
#
#
#
#
#
# 		1,100.60
# 2021.04.26
# 1,111.00
#   6.50
# 1,130.44
# 1,091.56
# 1,121.80
# 1,100.20
#
#
# 		N/A
#
#
#
#
#
#
# 		1,099.60
# 2021.04.23
# 1,117.50
#  0.00
# 1,137.05
# 1,097.95
# 1,128.40
# 1,106.60
#
#
# 		N/A
#
#
#
#
#
#
# 		1,106.00
# 2021.04.22
# 1,117.50
#   1.50
# 1,137.05
# 1,097.95
# 1,128.40
# 1,106.60
#
#
# 		N/A
#
#
#
#
#
#
# 		1,106.00
# 2021.04.21
# 1,119.00
#  4.50
# 1,138.58
# 1,099.42
# 1,129.90
# 1,108.10
#
#
# 		N/A
#
#
#
#
#
#
# 		1,107.50
# 2021.04.20
# 1,114.50
#   0.50
# 1,134.00
# 1,095.00
# 1,125.40
# 1,103.60
#
#
# 		N/A
#
#
#
#
#
#
# 		1,103.00
# 2021.04.19
# 1,115.00
#   2.00
# 1,134.51
# 1,095.49
# 1,125.90
# 1,104.10
#
#
# 		N/A
#
#
#
#
#
#
# 		1,103.50
# 2021.04.16
# 1,117.00
#  0.50
# 1,136.54
# 1,097.46
# 1,127.90
# 1,106.10
#
#
# 		N/A
#
#
#
#
#
#
# 		1,105.50
# 2021.04.15
# 1,116.50
#  1.00
# 1,136.03
# 1,096.97
# 1,127.40
# 1,105.60
#
#
# 		N/A
#
#
#
#
#
#
# 		1,105.00
# 2021.04.14
# 1,115.50
#   9.00
# 1,135.02
# 1,095.98
# 1,126.40
# 1,104.60
#
#
# 		N/A
#
#
#
#
#
#
# 		1,104.00
# 2021.04.13
# 1,124.50
#   0.50
# 1,144.17
# 1,104.83
# 1,135.50
# 1,113.50
#
#
# 		N/A
#
#
#
#
#
#
# 		1,112.89
# 2021.04.12
# 1,125.00
#  4.00
# 1,144.68
# 1,105.32
# 1,136.00
# 1,114.00
#
#
# 		N/A
#
#
#
#
#
#
# 		1,113.39
# 2021.04.09
# 1,121.00
#  3.50
# 1,140.61
# 1,101.39
# 1,131.90
# 1,110.10
#
#
# 		N/A
#
#
#
#
#
#
# 		1,109.49
# 2021.04.08
# 1,117.50
#   1.00
# 1,137.05
# 1,097.95
# 1,128.40
# 1,106.60
#
#
# 		N/A
#
#
#
#
#
#
# 		1,106.00
# 2021.04.07
# 1,118.50
#   3.00
# 1,138.07
# 1,098.93
# 1,129.40
# 1,107.60
#
#
# 		N/A
#
#
#
#
#
#
# 		1,107.00
# 2021.04.06
# 1,121.50
#   7.00
# 1,141.12
# 1,101.88
# 1,132.40
# 1,110.60
#
#
# 		N/A
#
#
#
#
#
#
# 		1,109.99
# 2021.04.05
# 1,128.50
#   0.50
# 1,148.24
# 1,108.76
# 1,139.50
# 1,117.50
#
#
# 		N/A
#
#
#
#
#
#
# 		1,116.89
# 2021.04.02
# 1,129.00
#   2.50
# 1,148.75
# 1,109.25
# 1,140.00
# 1,118.00
#
#
# 		N/A
#
#
#
#
#
#
# 		1,117.39
# 2021.04.01
# 1,131.50
#  1.50
# 1,151.30
# 1,111.70
# 1,142.50
# 1,120.50
#
#
# 		N/A
#
#
#
#
#
#
# 		1,119.89
# 2021.03.31
# 1,130.00
#   5.00
# 1,149.77
# 1,110.23
# 1,141.00
# 1,119.00
#
#
# 		N/A
#
#
#
#
#
#
# 		1,118.39
# 2021.03.30
# 1,135.00
#  2.50
# 1,154.86
# 1,115.14
# 1,146.10
# 1,123.90
#
#
# 		N/A
#
#
#
#
#
#
# 		1,123.29
# 2021.03.29
# 1,132.50
#  1.00
# 1,152.31
# 1,112.69
# 1,143.50
# 1,121.50
#
#
# 		N/A
#
#
#
#
#
#
# 		1,120.89
# 2021.03.26
# 1,131.50
#   3.00
# 1,151.30
# 1,111.70
# 1,142.50
# 1,120.50
#
#
# 		N/A
#
#
#
#
#
#
# 		1,119.89
# 2021.03.25
# 1,134.50
#  2.00
# 1,154.35
# 1,114.65
# 1,145.60
# 1,123.40
#
#
# 		N/A
#
#
#
#
#
#
# 		1,122.79
# 2021.03.24
# 1,132.50
#  2.00
# 1,152.31
# 1,112.69
# 1,143.50
# 1,121.50
#
#
# 		N/A
#
#
#
#
#
#
# 		1,120.89
# 2021.03.23
# 1,130.50
#  2.50
# 1,150.28
# 1,110.72
# 1,141.50
# 1,119.50
#
#
# 		N/A
#
#
#
#
#
#
# 		1,118.89
# 2021.03.22
# 1,128.00
#   2.00
# 1,147.74
# 1,108.26
# 1,139.00
# 1,117.00
#
#
# 		N/A
#
#
#
#
#
#
# 		1,116.39
# 2021.03.19
# 1,130.00
#  5.00
# 1,149.77
# 1,110.23
# 1,141.00
# 1,119.00
#
#
# 		N/A
#
#
#
#
#
#
# 		1,118.39
# 2021.03.18
# 1,125.00
#   4.50
# 1,144.68
# 1,105.32
# 1,136.00
# 1,114.00
#
#
# 		N/A
#
#
#
#
#
#
# 		1,113.39
# 2021.03.17
# 1,129.50
#   1.00
# 1,149.26
# 1,109.74
# 1,140.50
# 1,118.50
#
#
# 		N/A
#
#
#
#
#
#
# 		1,117.89
# 2021.03.16
# 1,130.50
#   3.00
# 1,150.28
# 1,110.72
# 1,141.50
# 1,119.50
#
#
# 		N/A
#
#
#
#
#
#
# 		1,118.89
# 2021.03.15
# 1,133.50
#   3.00
# 1,153.33
# 1,113.67
# 1,144.60
# 1,122.40
#
#
# 		N/A
#
#
#
#
#
#
# 		1,121.79
# 2021.03.12
# 1,136.50
#  3.50
# 1,156.38
# 1,116.62
# 1,147.60
# 1,125.40
#
#
# 		N/A
#
#
#
#
#
#
# 		1,124.79
# 2021.03.11
# 1,133.00
#   9.00
# 1,152.82
# 1,113.18
# 1,144.10
# 1,121.90
#
#
# 		N/A
#
#
#
#
#
#
# 		1,121.29
# 2021.03.10
# 1,142.00
#  3.50
# 1,161.98
# 1,122.02
# 1,153.10
# 1,130.90
#
#
# 		N/A
#
#
#
#
#
#
# 		1,130.28
# 2021.03.09
# 1,138.50
#  0.50
# 1,158.42
# 1,118.58
# 1,149.60
# 1,127.40
#
#
# 		N/A
#
#
#
#
#
#
# 		1,126.79
# 2021.03.08
# 1,138.00
#  9.00
# 1,157.91
# 1,118.09
# 1,149.10
# 1,126.90
#
#
# 		N/A
#
#
#
#
#
#
# 		1,126.29
# 2021.03.05
# 1,129.00
#  4.00
# 1,148.75
# 1,109.25
# 1,140.00
# 1,118.00
#
#
# 		N/A
#
#
#
#
#
#
# 		1,117.39
# 2021.03.04
# 1,125.00
#  2.50
# 1,144.68
# 1,105.32
# 1,136.00
# 1,114.00
#
#
# 		N/A
#
#
#
#
#
#
# 		1,113.39
# 2021.03.03
# 1,122.50
#   2.00
# 1,142.14
# 1,102.86
# 1,133.50
# 1,111.50
#
#
# 		N/A
#
#
#
#
#
#
# 		1,110.89
# 2021.03.02
# 1,124.50
#   1.50
# 1,144.17
# 1,104.83
# 1,135.50
# 1,113.50
#
#
# 		N/A
#
#
#
#
#
#
# 		1,112.89
# 2021.02.26
# 1,126.00
#  17.00
# 1,145.70
# 1,106.30
# 1,137.00
# 1,115.00
#
#
#
# 		1,139.51
#
#
#
#
#
# 		1,114.39
# 2021.02.25
# 1,109.00
#  0.00
# 1,128.40
# 1,089.60
# 1,119.80
# 1,098.20
#
#
#
# 		1,122.30
#
#
#
#
#
# 		1,097.60
# 2021.02.24
# 1,109.00
#   3.00
# 1,128.40
# 1,089.60
# 1,119.80
# 1,098.20
#
#
#
# 		1,122.30
#
#
#
#
#
# 		1,097.60
# 2021.02.23
# 1,112.00
#  0.00
# 1,131.46
# 1,092.54
# 1,122.80
# 1,101.20
#
#
#
# 		1,125.34
#
#
#
#
#
# 		1,100.60
# 2021.02.22
# 1,112.00
#  5.50
# 1,131.46
# 1,092.54
# 1,122.80
# 1,101.20
#
#
#
# 		1,125.34
#
#
#
#
#
# 		1,100.60
# 2021.02.19
# 1,106.50
#   0.50
# 1,125.86
# 1,087.14
# 1,117.30
# 1,095.70
#
#
#
# 		1,119.77
#
#
#
#
#
# 		1,095.10
# 2021.02.18
# 1,107.00
#   0.50
# 1,126.37
# 1,087.63
# 1,117.80
# 1,096.20
#
#
#
# 		1,120.28
#
#
#
#
#
# 		1,095.60
# 2021.02.17
# 1,107.50
#  5.50
# 1,126.88
# 1,088.12
# 1,118.30
# 1,096.70
#
#
#
# 		1,120.79
#
#
#
#
#
# 		1,096.10
# 2021.02.16
# 1,102.00
#   0.50
# 1,121.28
# 1,082.72
# 1,112.70
# 1,091.30
#
#
#
# 		1,115.22
#
#
#
#
#
# 		1,090.71
# 2021.02.15
# 1,102.50
#   4.50
# 1,121.79
# 1,083.21
# 1,113.30
# 1,091.70
#
#
#
# 		1,115.73
#
#
#
#
#
# 		1,091.11
# 2021.02.10
# 1,107.00
#   6.50
# 1,126.37
# 1,087.63
# 1,117.80
# 1,096.20
#
#
#
# 		1,120.28
#
#
#
#
#
# 		1,095.60
# 2021.02.09
# 1,113.50
#   7.50
# 1,132.98
# 1,094.02
# 1,124.40
# 1,102.60
#
#
#
# 		1,126.86
#
#
#
#
#
# 		1,102.00
# 2021.02.08
# 1,121.00
#   2.50
# 1,140.61
# 1,101.39
# 1,131.90
# 1,110.10
#
#
#
# 		1,134.45
#
#
#
#
#
# 		1,109.49
# 2021.02.05
# 1,123.50
#  5.00
# 1,143.16
# 1,103.84
# 1,134.50
# 1,112.50
#
#
#
# 		1,136.98
#
#
#
#
#
# 		1,111.89
# 2021.02.04
# 1,118.50
#  2.50
# 1,138.07
# 1,098.93
# 1,129.40
# 1,107.60
#
#
#
# 		1,131.92
#
#
#
#
#
# 		1,107.00
# 2021.02.03
# 1,116.00
#  0.00
# 1,135.53
# 1,096.47
# 1,126.90
# 1,105.10
#
#
#
# 		1,129.39
#
#
#
#
#
# 		1,104.50
# 2021.02.02
# 1,116.00
#   3.50
# 1,135.53
# 1,096.47
# 1,126.90
# 1,105.10
#
#
#
# 		1,129.39
#
#
#
#
#
# 		1,104.50
# 2021.02.01
# 1,119.50
#  2.00
# 1,139.09
# 1,099.91
# 1,130.40
# 1,108.60
#
#
#
# 		1,132.93
#
#
#
#
#
# 		1,107.99
# 2021.01.29
# 1,117.50
#   0.50
# 1,137.05
# 1,097.95
# 1,128.40
# 1,106.60
#
#
#
# 		1,130.91
#
#
#
#
#
# 		1,105.99
# 2021.01.28
# 1,118.00
#  13.00
# 1,137.56
# 1,098.44
# 1,128.90
# 1,107.10
#
#
#
# 		1,131.41
#
#
#
#
#
# 		1,106.49
# 2021.01.27
# 1,105.00
#   0.50
# 1,124.33
# 1,085.67
# 1,115.80
# 1,094.20
#
#
#
# 		1,118.26
#
#
#
#
#
# 		1,093.60
# 2021.01.26
# 1,105.50
#  3.00
# 1,124.84
# 1,086.16
# 1,116.30
# 1,094.70
#
#
#
# 		1,118.76
#
#
#
#
#
# 		1,094.10
# 2021.01.25
# 1,102.50
#   2.50
# 1,121.79
# 1,083.21
# 1,113.30
# 1,091.70
#
#
#
# 		1,115.73
#
#
#
#
#
# 		1,091.10
# 2021.01.22
# 1,105.00
#  4.00
# 1,124.33
# 1,085.67
# 1,115.80
# 1,094.20
#
#
#
# 		1,118.26
#
#
#
#
#
# 		1,093.60
# 2021.01.21
# 1,101.00
#   0.50
# 1,120.26
# 1,081.74
# 1,111.70
# 1,090.30
#
#
#
# 		1,114.21
#
#
#
#
#
# 		1,089.70
# 2021.01.20
# 1,101.50
#   1.00
# 1,120.77
# 1,082.23
# 1,112.20
# 1,090.80
#
#
#
# 		1,114.71
#
#
#
#
#
# 		1,090.20
# 2021.01.19
# 1,102.50
#   4.50
# 1,121.79
# 1,083.21
# 1,113.30
# 1,091.70
#
#
#
# 		1,115.73
#
#
#
#
#
# 		1,091.10
# 2021.01.18
# 1,107.00
#  3.50
# 1,126.37
# 1,087.63
# 1,117.80
# 1,096.20
#
#
#
# 		1,120.28
#
#
#
#
#
# 		1,095.60
# 2021.01.15
# 1,103.50
#  7.50
# 1,122.81
# 1,084.19
# 1,114.30
# 1,092.70
#
#
#
# 		1,116.74
#
#
#
#
#
# 		1,092.10
# 2021.01.14
# 1,096.00
#   1.00
# 1,115.18
# 1,076.82
# 1,106.70
# 1,085.30
#
#
#
# 		1,109.15
#
#
#
#
#
# 		1,084.70
# 2021.01.13
# 1,097.00
#   2.00
# 1,116.19
# 1,077.81
# 1,107.70
# 1,086.30
#
#
#
# 		1,110.16
#
#
#
#
#
# 		1,085.70
# 2021.01.12
# 1,099.00
#  1.00
# 1,118.23
# 1,079.77
# 1,109.70
# 1,088.30
#
#
#
# 		1,112.18
#
#
#
#
#
# 		1,087.70
# 2021.01.11
# 1,098.00
#  6.00
# 1,117.21
# 1,078.79
# 1,108.70
# 1,087.30
#
#
#
# 		1,111.17
#
#
#
#
#
# 		1,086.70
# 2021.01.08
# 1,092.00
#  0.00
# 1,111.11
# 1,072.89
# 1,102.70
# 1,081.30
#
#
#
# 		1,105.10
#
#
#
#
#
# 		1,080.70
# 2021.01.07
# 1,092.00
#  5.50
# 1,111.11
# 1,072.89
# 1,102.70
# 1,081.30
#
#
#
# 		1,105.10
#
#
#
#
#
# 		1,080.70
# 2021.01.06
# 1,086.50
#   2.50
# 1,105.51
# 1,067.49
# 1,097.10
# 1,075.90
#
#
#
# 		1,099.53
#
#
#
#
#
# 		1,075.31
# 2021.01.05
# 1,089.00
#  6.50
# 1,108.05
# 1,069.95
# 1,099.60
# 1,078.40
#
#
#
# 		1,102.06
#
#
#
#
#
# 		1,077.80
# 2021.01.04
# 1,082.50
#   5.50
# 1,101.44
# 1,063.56
# 1,093.10
# 1,071.90
#
#
#
# 		1,095.49
#
#
#
#
#
# 		1,071.31
# 2020.12.31
# 1,088.00
#  0.50
# 1,107.04
# 1,068.96
# 1,098.60
# 1,077.40
#
#
#
# 		1,101.05
#
#
#
#
#
# 		1,076.80
# 2020.12.30
# 1,087.50
#   6.00
# 1,106.53
# 1,068.47
# 1,098.10
# 1,076.90
#
#
#
# 		1,100.55
#
#
#
#
#
# 		1,076.30
# 2020.12.29
# 1,093.50
#   3.00
# 1,112.63
# 1,074.37
# 1,104.20
# 1,082.80
#
#
#
# 		1,106.62
#
#
#
#
#
# 		1,082.20
# 2020.12.28
# 1,096.50
#   7.00
# 1,115.68
# 1,077.32
# 1,107.20
# 1,085.80
#
#
#
# 		1,109.65
#
#
#
#
#
# 		1,085.20
# 2020.12.24
# 1,103.50
#   4.00
# 1,122.81
# 1,084.19
# 1,114.30
# 1,092.70
#
#
#
# 		1,116.74
#
#
#
#
#
# 		1,092.09
# 2020.12.23
# 1,107.50
#  1.00
# 1,126.88
# 1,088.12
# 1,118.30
# 1,096.70
#
#
#
# 		1,120.79
#
#
#
#
#
# 		1,096.09
# 2020.12.22
# 1,106.50
#   2.50
# 1,125.86
# 1,087.14
# 1,117.30
# 1,095.70
#
#
#
# 		1,119.77
#
#
#
#
#
# 		1,095.09
# 2020.12.21
# 1,109.00
#  9.50
# 1,128.40
# 1,089.60
# 1,119.80
# 1,098.20
#
#
#
# 		1,122.30
#
#
#
#
#
# 		1,097.59
# 2020.12.18
# 1,099.50
#  5.50
# 1,118.74
# 1,080.26
# 1,110.20
# 1,088.80
#
#
#
# 		1,112.69
#
#
#
#
#
# 		1,088.19
# 2020.12.17
# 1,094.00
#  3.00
# 1,113.14
# 1,074.86
# 1,104.70
# 1,083.30
#
#
#
# 		1,107.12
#
#
#
#
#
# 		1,082.69
# 2020.12.16
# 1,091.00
#   3.50
# 1,110.09
# 1,071.91
# 1,101.60
# 1,080.40
#
#
#
# 		1,104.09
#
#
#
#
#
# 		1,079.80
# 2020.12.15
# 1,094.50
#  2.00
# 1,113.65
# 1,075.35
# 1,105.20
# 1,083.80
#
#
#
# 		1,107.63
#
#
#
#
#
# 		1,083.20
# 2020.12.14
# 1,092.50
#  0.50
# 1,111.61
# 1,073.39
# 1,103.20
# 1,081.80
#
#
#
# 		1,105.61
#
#
#
#
#
# 		1,081.20
# 2020.12.11
# 1,092.00
#  3.50
# 1,111.11
# 1,072.89
# 1,102.70
# 1,081.30
#
#
#
# 		1,105.10
#
#
#
#
#
# 		1,080.70

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(10):
    res = requests.get('https://finance.naver.com/marketindex/exchangeDailyQuote.nhn?marketindexCd=FX_USDKRW&page=' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('table.tbl_exchange.today tbody tr')
    for item in data:
        print (item.find('td',{'class':'date'}).get_text().strip()+' --> '+item.find('td',{'class':'num'}).get_text().strip() )
# Out:
# 2021.05.07 --> 1,120.50
# 2021.05.06 --> 1,124.00
# 2021.05.04 --> 1,126.00
# 2021.05.03 --> 1,123.00
# 2021.04.30 --> 1,117.50
# 2021.04.29 --> 1,108.50
# 2021.04.28 --> 1,114.00
# 2021.04.27 --> 1,112.00
# 2021.04.26 --> 1,111.00
# 2021.04.23 --> 1,117.50
# 2021.04.22 --> 1,117.50
# 2021.04.21 --> 1,119.00
# 2021.04.20 --> 1,114.50
# 2021.04.19 --> 1,115.00
# 2021.04.16 --> 1,117.00
# 2021.04.15 --> 1,116.50
# 2021.04.14 --> 1,115.50
# 2021.04.13 --> 1,124.50
# 2021.04.12 --> 1,125.00
# 2021.04.09 --> 1,121.00
# 2021.04.08 --> 1,117.50
# 2021.04.07 --> 1,118.50
# 2021.04.06 --> 1,121.50
# 2021.04.05 --> 1,128.50
# 2021.04.02 --> 1,129.00
# 2021.04.01 --> 1,131.50
# 2021.03.31 --> 1,130.00
# 2021.03.30 --> 1,135.00
# 2021.03.29 --> 1,132.50
# 2021.03.26 --> 1,131.50
# 2021.03.25 --> 1,134.50
# 2021.03.24 --> 1,132.50
# 2021.03.23 --> 1,130.50
# 2021.03.22 --> 1,128.00
# 2021.03.19 --> 1,130.00
# 2021.03.18 --> 1,125.00
# 2021.03.17 --> 1,129.50
# 2021.03.16 --> 1,130.50
# 2021.03.15 --> 1,133.50
# 2021.03.12 --> 1,136.50
# 2021.03.11 --> 1,133.00
# 2021.03.10 --> 1,142.00
# 2021.03.09 --> 1,138.50
# 2021.03.08 --> 1,138.00
# 2021.03.05 --> 1,129.00
# 2021.03.04 --> 1,125.00
# 2021.03.03 --> 1,122.50
# 2021.03.02 --> 1,124.50
# 2021.02.26 --> 1,126.00
# 2021.02.25 --> 1,109.00
# 2021.02.24 --> 1,109.00
# 2021.02.23 --> 1,112.00
# 2021.02.22 --> 1,112.00
# 2021.02.19 --> 1,106.50
# 2021.02.18 --> 1,107.00
# 2021.02.17 --> 1,107.50
# 2021.02.16 --> 1,102.00
# 2021.02.15 --> 1,102.50
# 2021.02.10 --> 1,107.00
# 2021.02.09 --> 1,113.50
# 2021.02.08 --> 1,121.00
# 2021.02.05 --> 1,123.50
# 2021.02.04 --> 1,118.50
# 2021.02.03 --> 1,116.00
# 2021.02.02 --> 1,116.00
# 2021.02.01 --> 1,119.50
# 2021.01.29 --> 1,117.50
# 2021.01.28 --> 1,118.00
# 2021.01.27 --> 1,105.00
# 2021.01.26 --> 1,105.50
# 2021.01.25 --> 1,102.50
# 2021.01.22 --> 1,105.00
# 2021.01.21 --> 1,101.00
# 2021.01.20 --> 1,101.50
# 2021.01.19 --> 1,102.50
# 2021.01.18 --> 1,107.00
# 2021.01.15 --> 1,103.50
# 2021.01.14 --> 1,096.00
# 2021.01.13 --> 1,097.00
# 2021.01.12 --> 1,099.00
# 2021.01.11 --> 1,098.00
# 2021.01.08 --> 1,092.00
# 2021.01.07 --> 1,092.00
# 2021.01.06 --> 1,086.50
# 2021.01.05 --> 1,089.00
# 2021.01.04 --> 1,082.50
# 2020.12.31 --> 1,088.00
# 2020.12.30 --> 1,087.50
# 2020.12.29 --> 1,093.50
# 2020.12.28 --> 1,096.50
# 2020.12.24 --> 1,103.50
# 2020.12.23 --> 1,107.50
# 2020.12.22 --> 1,106.50
# 2020.12.21 --> 1,109.00
# 2020.12.18 --> 1,099.50
# 2020.12.17 --> 1,094.00
# 2020.12.16 --> 1,091.00
# 2020.12.15 --> 1,094.50
# 2020.12.14 --> 1,092.50
# 2020.12.11 --> 1,092.00

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(10):
    res = requests.get('https://finance.naver.com/marketindex/exchangeDailyQuote.nhn?marketindexCd=FX_USDKRW&page=' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('table.tbl_exchange.today tbody tr')
    for item in data:
        print (item.get_text().strip().split('\n')[0])
# Out:
# 2021.05.07
# 2021.05.06
# 2021.05.04
# 2021.05.03
# 2021.04.30
# 2021.04.29
# 2021.04.28
# 2021.04.27
# 2021.04.26
# 2021.04.23
# 2021.04.22
# 2021.04.21
# 2021.04.20
# 2021.04.19
# 2021.04.16
# 2021.04.15
# 2021.04.14
# 2021.04.13
# 2021.04.12
# 2021.04.09
# 2021.04.08
# 2021.04.07
# 2021.04.06
# 2021.04.05
# 2021.04.02
# 2021.04.01
# 2021.03.31
# 2021.03.30
# 2021.03.29
# 2021.03.26
# 2021.03.25
# 2021.03.24
# 2021.03.23
# 2021.03.22
# 2021.03.19
# 2021.03.18
# 2021.03.17
# 2021.03.16
# 2021.03.15
# 2021.03.12
# 2021.03.11
# 2021.03.10
# 2021.03.09
# 2021.03.08
# 2021.03.05
# 2021.03.04
# 2021.03.03
# 2021.03.02
# 2021.02.26
# 2021.02.25
# 2021.02.24
# 2021.02.23
# 2021.02.22
# 2021.02.19
# 2021.02.18
# 2021.02.17
# 2021.02.16
# 2021.02.15
# 2021.02.10
# 2021.02.09
# 2021.02.08
# 2021.02.05
# 2021.02.04
# 2021.02.03
# 2021.02.02
# 2021.02.01
# 2021.01.29
# 2021.01.28
# 2021.01.27
# 2021.01.26
# 2021.01.25
# 2021.01.22
# 2021.01.21
# 2021.01.20
# 2021.01.19
# 2021.01.18
# 2021.01.15
# 2021.01.14
# 2021.01.13
# 2021.01.12
# 2021.01.11
# 2021.01.08
# 2021.01.07
# 2021.01.06
# 2021.01.05
# 2021.01.04
# 2020.12.31
# 2020.12.30
# 2020.12.29
# 2020.12.28
# 2020.12.24
# 2020.12.23
# 2020.12.22
# 2020.12.21
# 2020.12.18
# 2020.12.17
# 2020.12.16
# 2020.12.15
# 2020.12.14
# 2020.12.11

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(10):
    res = requests.get('https://finance.naver.com/marketindex/exchangeDailyQuote.nhn?marketindexCd=FX_USDKRW&page=' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('table.tbl_exchange.today tbody tr')
    for item in data:
        print (item.get_text().strip().split('\n')[1])
# Out:
# 1,120.50
# 1,124.00
# 1,126.00
# 1,123.00
# 1,117.50
# 1,108.50
# 1,114.00
# 1,112.00
# 1,111.00
# 1,117.50
# 1,117.50
# 1,119.00
# 1,114.50
# 1,115.00
# 1,117.00
# 1,116.50
# 1,115.50
# 1,124.50
# 1,125.00
# 1,121.00
# 1,117.50
# 1,118.50
# 1,121.50
# 1,128.50
# 1,129.00
# 1,131.50
# 1,130.00
# 1,135.00
# 1,132.50
# 1,131.50
# 1,134.50
# 1,132.50
# 1,130.50
# 1,128.00
# 1,130.00
# 1,125.00
# 1,129.50
# 1,130.50
# 1,133.50
# 1,136.50
# 1,133.00
# 1,142.00
# 1,138.50
# 1,138.00
# 1,129.00
# 1,125.00
# 1,122.50
# 1,124.50
# 1,126.00
# 1,109.00
# 1,109.00
# 1,112.00
# 1,112.00
# 1,106.50
# 1,107.00
# 1,107.50
# 1,102.00
# 1,102.50
# 1,107.00
# 1,113.50
# 1,121.00
# 1,123.50
# 1,118.50
# 1,116.00
# 1,116.00
# 1,119.50
# 1,117.50
# 1,118.00
# 1,105.00
# 1,105.50
# 1,102.50
# 1,105.00
# 1,101.00
# 1,101.50
# 1,102.50
# 1,107.00
# 1,103.50
# 1,096.00
# 1,097.00
# 1,099.00
# 1,098.00
# 1,092.00
# 1,092.00
# 1,086.50
# 1,089.00
# 1,082.50
# 1,088.00
# 1,087.50
# 1,093.50
# 1,096.50
# 1,103.50
# 1,107.50
# 1,106.50
# 1,109.00
# 1,099.50
# 1,094.00
# 1,091.00
# 1,094.50
# 1,092.50
# 1,092.00

# %%
import requests
from bs4 import BeautifulSoup

exchange_rate={}
for page_num in range(10):
    res = requests.get('https://finance.naver.com/marketindex/exchangeDailyQuote.nhn?marketindexCd=FX_USDKRW&page=' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('table.tbl_exchange.today tbody tr')
    for item in data:
        exchange_rate[item.find('td',{'class':'date'}).get_text().strip()] = float(item.find('td',{'class':'num'}).get_text().strip().replace(',',''))   
#print(exchange_rate)
purchase_amount=1113
purchase_date={}
for date in exchange_rate:
    if exchange_rate[date]<1113 :
        purchase_date[date]=exchange_rate[date]
        
print(purchase_date)
# Out:
# {'2021.04.29': 1108.5, '2021.04.27': 1112.0, '2021.04.26': 1111.0, '2021.02.25': 1109.0, '2021.02.24': 1109.0, '2021.02.23': 1112.0, '2021.02.22': 1112.0, '2021.02.19': 1106.5, '2021.02.18': 1107.0, '2021.02.17': 1107.5, '2021.02.16': 1102.0, '2021.02.15': 1102.5, '2021.02.10': 1107.0, '2021.01.27': 1105.0, '2021.01.26': 1105.5, '2021.01.25': 1102.5, '2021.01.22': 1105.0, '2021.01.21': 1101.0, '2021.01.20': 1101.5, '2021.01.19': 1102.5, '2021.01.18': 1107.0, '2021.01.15': 1103.5, '2021.01.14': 1096.0, '2021.01.13': 1097.0, '2021.01.12': 1099.0, '2021.01.11': 1098.0, '2021.01.08': 1092.0, '2021.01.07': 1092.0, '2021.01.06': 1086.5, '2021.01.05': 1089.0, '2021.01.04': 1082.5, '2020.12.31': 1088.0, '2020.12.30': 1087.5, '2020.12.29': 1093.5, '2020.12.28': 1096.5, '2020.12.24': 1103.5, '2020.12.23': 1107.5, '2020.12.22': 1106.5, '2020.12.21': 1109.0, '2020.12.18': 1099.5, '2020.12.17': 1094.0, '2020.12.16': 1091.0, '2020.12.15': 1094.5, '2020.12.14': 1092.5, '2020.12.11': 1092.0}
