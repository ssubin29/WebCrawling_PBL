# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

chromedriver = 'C:/dev_python/Webdriver/chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://lms.sungshin.ac.kr/ilos/main/member/login_form.acl')

#ID
elem = driver.find_element_by_name("loginId")
elem.clear()
elem.send_keys("")

#PW
elem = driver.find_element_by_name("loginPwd")
elem.send_keys("")
elem.send_keys(Keys.RETURN)

time.sleep(3)

#마이페이지 클릭
button = driver.find_element_by_id("user_photo")
button.click()

#수강과목 클릭
button_1 = driver.find_element_by_id("menu_mp_register")
button_1.click()

loop, count = True,0

while loop and count <10:
    try:
        #이전학기 더보기
        button_2 = driver.find_element_by_id("onceLecture")
        button_2.click()

        #수강과목 리스트(2020-1학기)
        subjects = driver.find_element_by_css_selector("#lecture_list")
        print(subjects.text)
    except:
        loop = False
# Out:
# 2021-1학기 정규과목
# 고급C++프로그래밍(004)
# 김설현
# 수/1-3
# 시스템프로그래밍(001)
# 심광섭
# 화/4-6
# 웹프로그래밍기초(005)
# 고다혜
# 목/7-9
# 자료구조(001)
# 장재경
# 화/7-9
# 자바프로그래밍(009)
# 이윤경
# 월/4-6
# 컴퓨터구조(001)
# 김준철
# 수/4-6
# 2020-겨울학기 정규과목
# 프로그래밍과 문제해결(001)
# 김의찬
# (001)
# 2020-2학기 정규과목
# C++프로그래밍(006)
# 이택
# 목/10-12(006)
# 데이터베이스(001)
# 장재경
# 목/1-3(001)
# 디지털컨텐츠(004)
# 한세영
# 수/10-12(004)
# 문화인류학으로 세상보기(001)
# 김길웅
# (001)
# 생활 한자(001)
# 김용재
# (001)
# 운영체제(001)
# 심광섭
# 화/7-9(001)
# 2020-1학기 정규과목
# IT개론(002)
# 이재원
# 화/4-6(002)
# 논리회로(001)
# 이윤경
# 월/1-3(001)
# 문학과 시대 읽기(001)
# 김길웅
# 금/10-12(001)
# 소프트웨어융합기술개론(003)
# 이일구
# 월/10-12(003)
# 컴퓨터시스템관리(002)
# 김종완
# 화/1-3(002)
# 파이썬프로그래밍(010)
# 이택
# 화/10-12(010)
# 웹프로그래밍기초(005)
# 서유현
# 목/10-12(005)
# 이전 학기 더보기
# 비정규과목
# 2021-1학기 러닝스터디(01)
# 한아름
# 2021.04.12 ~ 2021.05.14
# 2021년도 재학생 온라인 인권 및 젠더폭력예방 교육(11)
# 박현미
# 2021.04.01 ~ 2021.12.31
# [2021학년도 신입생을 위한 온라인 학습전략워크숍-공과대학입문기초](01)
# 한아름
# 2021.03.02 ~ 2021.04.23
# [학생] 연구실 및 실험실습실 사용자 안전교육 정기2반(01)
# 전길용
# 2021.03.10 ~ 2021.06.29
# 삼성 코딩테스트 기출 유사문제 풀이 영상(디퓨저)(01)
# 박혜진
# 2021.02.01 ~ 2021.07.31
# 수강취소하기
# 삼성 코딩테스트 기출 유사문제 풀이 영상(알파윷)(01)
# 박혜진
# 2021.02.01 ~ 2021.07.31
# 수강취소하기
# 정보보안기사/정보처리기사 자격증 준비/취득 방법 특강(01)
# 이일구
# 2021.06.28 ~ 2021.07.28
# 2020년도 온라인 장애 인식개선 교육(05)
# 김경내
# 2020.12.02 ~ 2020.12.31
# 2020년도 재학생 온라인 인권 및 젠더폭력예방 교육(12)
# 박현미
# 2020.05.11 ~ 2020.12.31
# [공과대학 입문기초] 공학과 지식재산권(01)
# DAVAASUREN BOLOR
# 2020.03.10 ~ 2020.05.29
# 내 마음의 쉼표(마음챙김 명상 및 이완 프로그램)(05)
# 조아라
# 2020.05.20 ~ 2020.06.30
# 내 마음의 쉼표(온라인 마음챙김 명상 및 이완 프로그램)(05)
# 정은지
# 2020.11.23 ~ 2021.01.31
# 온라인 자살예방교육(05)
# 조아라
# 2020.05.20 ~ 2020.06.30
# 융합보안학과 - 취업 선배 특강:취업 사례 소개(01)
# 이일구
# 2020.09.18 ~ 2020.10.30
# 퀀트와 금융프로그래밍 특강(01)
# 박새롬
# 2020.05.06 ~ 2020.06.12
# 클라우드 컴퓨팅 특강(01)
# 박새롬
# 2020.05.06 ~ 2020.06.12
# 2019 온라인 장애인식 교육 - 학부생(06)
# 김경내
# 2019.11.13 ~ 2019.12.27
# 2019년 온라인자살예방교육 - 학부생(03)
# 조아라
# 2019.10.15 ~ 2019.11.29
# 2019학년도 1학기 성신스터디그룹 오리엔테이션(00)
# 서민휘
# 2019.03.18 ~ 2019.07.19
# 2019학년도 2학기 성신스터디그룹(02)
# 서민휘
# 2019.09.19 ~ 2020.01.18
# 2019학년도 온라인 인권교육 및 젠더폭력예방교육 - 학생(02)
# 박현미
# 2019.09.23 ~ 2019.12.31
# [온라인 학습전략 워크숍] 학습문제 개선전략(00)
# 서민휘
# 2019.04.08 ~ 2019.08.01
# 2021-1학기 정규과목
# 고급C++프로그래밍(004)
# 김설현
# 수/1-3
# 시스템프로그래밍(001)
# 심광섭
# 화/4-6
# 웹프로그래밍기초(005)
# 고다혜
# 목/7-9
# 자료구조(001)
# 장재경
# 화/7-9
# 자바프로그래밍(009)
# 이윤경
# 월/4-6
# 컴퓨터구조(001)
# 김준철
# 수/4-6
# 2020-겨울학기 정규과목
# 프로그래밍과 문제해결(001)
# 김의찬
# (001)
# 2020-2학기 정규과목
# C++프로그래밍(006)
# 이택
# 목/10-12(006)
# 데이터베이스(001)
# 장재경
# 목/1-3(001)
# 디지털컨텐츠(004)
# 한세영
# 수/10-12(004)
# 문화인류학으로 세상보기(001)
# 김길웅
# (001)
# 생활 한자(001)
# 김용재
# (001)
# 운영체제(001)
# 심광섭
# 화/7-9(001)
# 2020-1학기 정규과목
# IT개론(002)
# 이재원
# 화/4-6(002)
# 논리회로(001)
# 이윤경
# 월/1-3(001)
# 문학과 시대 읽기(001)
# 김길웅
# 금/10-12(001)
# 소프트웨어융합기술개론(003)
# 이일구
# 월/10-12(003)
# 컴퓨터시스템관리(002)
# 김종완
# 화/1-3(002)
# 파이썬프로그래밍(010)
# 이택
# 화/10-12(010)
# 웹프로그래밍기초(005)
# 서유현
# 목/10-12(005)
# 2019-겨울학기 정규과목
# 설득의 과학(01)
# 소현진
# (01)
# 2019-2학기 정규과목
# 문화와 일상으로 본 서양사(01)
# 오경환
# (01)
# 식품미생물학(01)
# 현정은
# 월-7,8,9(01)
# 영양학(01)
# 이승민
# 목-1,2,3(01)
# 유기화학(01)
# 표영희
# 화-4,5,6(01)
# 인체생리학(01)
# 정윤경
# 수-4,5,6(01)
# 창조적 사고와 글쓰기(33)
# 박근예
# 금-1,2,3(33)
# 이전 학기 더보기
# 비정규과목
# 2021-1학기 러닝스터디(01)
# 한아름
# 2021.04.12 ~ 2021.05.14
# 2021년도 재학생 온라인 인권 및 젠더폭력예방 교육(11)
# 박현미
# 2021.04.01 ~ 2021.12.31
# [2021학년도 신입생을 위한 온라인 학습전략워크숍-공과대학입문기초](01)
# 한아름
# 2021.03.02 ~ 2021.04.23
# [학생] 연구실 및 실험실습실 사용자 안전교육 정기2반(01)
# 전길용
# 2021.03.10 ~ 2021.06.29
# 삼성 코딩테스트 기출 유사문제 풀이 영상(디퓨저)(01)
# 박혜진
# 2021.02.01 ~ 2021.07.31
# 수강취소하기
# 삼성 코딩테스트 기출 유사문제 풀이 영상(알파윷)(01)
# 박혜진
# 2021.02.01 ~ 2021.07.31
# 수강취소하기
# 정보보안기사/정보처리기사 자격증 준비/취득 방법 특강(01)
# 이일구
# 2021.06.28 ~ 2021.07.28
# 2020년도 온라인 장애 인식개선 교육(05)
# 김경내
# 2020.12.02 ~ 2020.12.31
# 2020년도 재학생 온라인 인권 및 젠더폭력예방 교육(12)
# 박현미
# 2020.05.11 ~ 2020.12.31
# [공과대학 입문기초] 공학과 지식재산권(01)
# DAVAASUREN BOLOR
# 2020.03.10 ~ 2020.05.29
# 내 마음의 쉼표(마음챙김 명상 및 이완 프로그램)(05)
# 조아라
# 2020.05.20 ~ 2020.06.30
# 내 마음의 쉼표(온라인 마음챙김 명상 및 이완 프로그램)(05)
# 정은지
# 2020.11.23 ~ 2021.01.31
# 온라인 자살예방교육(05)
# 조아라
# 2020.05.20 ~ 2020.06.30
# 융합보안학과 - 취업 선배 특강:취업 사례 소개(01)
# 이일구
# 2020.09.18 ~ 2020.10.30
# 퀀트와 금융프로그래밍 특강(01)
# 박새롬
# 2020.05.06 ~ 2020.06.12
# 클라우드 컴퓨팅 특강(01)
# 박새롬
# 2020.05.06 ~ 2020.06.12
# 2019 온라인 장애인식 교육 - 학부생(06)
# 김경내
# 2019.11.13 ~ 2019.12.27
# 2019년 온라인자살예방교육 - 학부생(03)
# 조아라
# 2019.10.15 ~ 2019.11.29
# 2019학년도 1학기 성신스터디그룹 오리엔테이션(00)
# 서민휘
# 2019.03.18 ~ 2019.07.19
# 2019학년도 2학기 성신스터디그룹(02)
# 서민휘
# 2019.09.19 ~ 2020.01.18
# 2019학년도 온라인 인권교육 및 젠더폭력예방교육 - 학생(02)
# 박현미
# 2019.09.23 ~ 2019.12.31
# [온라인 학습전략 워크숍] 학습문제 개선전략(00)
# 서민휘
# 2019.04.08 ~ 2019.08.01
# 2021-1학기 정규과목
# 고급C++프로그래밍(004)
# 김설현
# 수/1-3
# 시스템프로그래밍(001)
# 심광섭
# 화/4-6
# 웹프로그래밍기초(005)
# 고다혜
# 목/7-9
# 자료구조(001)
# 장재경
# 화/7-9
# 자바프로그래밍(009)
# 이윤경
# 월/4-6
# 컴퓨터구조(001)
# 김준철
# 수/4-6
# 2020-겨울학기 정규과목
# 프로그래밍과 문제해결(001)
# 김의찬
# (001)
# 2020-2학기 정규과목
# C++프로그래밍(006)
# 이택
# 목/10-12(006)
# 데이터베이스(001)
# 장재경
# 목/1-3(001)
# 디지털컨텐츠(004)
# 한세영
# 수/10-12(004)
# 문화인류학으로 세상보기(001)
# 김길웅
# (001)
# 생활 한자(001)
# 김용재
# (001)
# 운영체제(001)
# 심광섭
# 화/7-9(001)
# 2020-1학기 정규과목
# IT개론(002)
# 이재원
# 화/4-6(002)
# 논리회로(001)
# 이윤경
# 월/1-3(001)
# 문학과 시대 읽기(001)
# 김길웅
# 금/10-12(001)
# 소프트웨어융합기술개론(003)
# 이일구
# 월/10-12(003)
# 컴퓨터시스템관리(002)
# 김종완
# 화/1-3(002)
# 파이썬프로그래밍(010)
# 이택
# 화/10-12(010)
# 웹프로그래밍기초(005)
# 서유현
# 목/10-12(005)
# 2019-겨울학기 정규과목
# 설득의 과학(01)
# 소현진
# (01)
# 2019-2학기 정규과목
# 문화와 일상으로 본 서양사(01)
# 오경환
# (01)
# 식품미생물학(01)
# 현정은
# 월-7,8,9(01)
# 영양학(01)
# 이승민
# 목-1,2,3(01)
# 유기화학(01)
# 표영희
# 화-4,5,6(01)
# 인체생리학(01)
# 정윤경
# 수-4,5,6(01)
# 창조적 사고와 글쓰기(33)
# 박근예
# 금-1,2,3(33)
# 2019-1학기 정규과목
# C 프로그래밍 입문(01)
# 김경진
# 목-4,5,6(01)
# 공통 스마트 IT 기술의 현재와 미래(01)
# 장현미
# 월-1,2,3(01)
# 동∙서 철학의 만남(01)
# 조정은
# 금-4,5,6(01)
# 비판적 사고와 토론(25)
# 최진호
# 수-1,2,3(25)
# 식품학(01)
# 표영희
# 화-4,5,6(01)
# 일반화학(01)
# 김정수
# 금-7,8,9(01)
# 전공별 진로탐색(23)
# 이정은
# 월-10(23)
# 비정규과목
# 2021-1학기 러닝스터디(01)
# 한아름
# 2021.04.12 ~ 2021.05.14
# 2021년도 재학생 온라인 인권 및 젠더폭력예방 교육(11)
# 박현미
# 2021.04.01 ~ 2021.12.31
# [2021학년도 신입생을 위한 온라인 학습전략워크숍-공과대학입문기초](01)
# 한아름
# 2021.03.02 ~ 2021.04.23
# [학생] 연구실 및 실험실습실 사용자 안전교육 정기2반(01)
# 전길용
# 2021.03.10 ~ 2021.06.29
# 삼성 코딩테스트 기출 유사문제 풀이 영상(디퓨저)(01)
# 박혜진
# 2021.02.01 ~ 2021.07.31
# 수강취소하기
# 삼성 코딩테스트 기출 유사문제 풀이 영상(알파윷)(01)
# 박혜진
# 2021.02.01 ~ 2021.07.31
# 수강취소하기
# 정보보안기사/정보처리기사 자격증 준비/취득 방법 특강(01)
# 이일구
# 2021.06.28 ~ 2021.07.28
# 2020년도 온라인 장애 인식개선 교육(05)
# 김경내
# 2020.12.02 ~ 2020.12.31
# 2020년도 재학생 온라인 인권 및 젠더폭력예방 교육(12)
# 박현미
# 2020.05.11 ~ 2020.12.31
# [공과대학 입문기초] 공학과 지식재산권(01)
# DAVAASUREN BOLOR
# 2020.03.10 ~ 2020.05.29
# 내 마음의 쉼표(마음챙김 명상 및 이완 프로그램)(05)
# 조아라
# 2020.05.20 ~ 2020.06.30
# 내 마음의 쉼표(온라인 마음챙김 명상 및 이완 프로그램)(05)
# 정은지
# 2020.11.23 ~ 2021.01.31
# 온라인 자살예방교육(05)
# 조아라
# 2020.05.20 ~ 2020.06.30
# 융합보안학과 - 취업 선배 특강:취업 사례 소개(01)
# 이일구
# 2020.09.18 ~ 2020.10.30
# 퀀트와 금융프로그래밍 특강(01)
# 박새롬
# 2020.05.06 ~ 2020.06.12
# 클라우드 컴퓨팅 특강(01)
# 박새롬
# 2020.05.06 ~ 2020.06.12
# 2019 온라인 장애인식 교육 - 학부생(06)
# 김경내
# 2019.11.13 ~ 2019.12.27
# 2019년 온라인자살예방교육 - 학부생(03)
# 조아라
# 2019.10.15 ~ 2019.11.29
# 2019학년도 1학기 성신스터디그룹 오리엔테이션(00)
# 서민휘
# 2019.03.18 ~ 2019.07.19
# 2019학년도 2학기 성신스터디그룹(02)
# 서민휘
# 2019.09.19 ~ 2020.01.18
# 2019학년도 온라인 인권교육 및 젠더폭력예방교육 - 학생(02)
# 박현미
# 2019.09.23 ~ 2019.12.31
# [온라인 학습전략 워크숍] 학습문제 개선전략(00)
# 서민휘
# 2019.04.08 ~ 2019.08.01
