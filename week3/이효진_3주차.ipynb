# %%
#영화랭킹 크롤링
import requests
from bs4 import BeautifulSoup

res = requests.get('https://movie.naver.com/movie/sdb/rank/rmovie.nhn')
soup = BeautifulSoup(res.content, 'html.parser')
data = soup.select('#old_content > table > tbody > tr > td > div > a')
for data in data:
   print (data.get_text())
# Out:
# 더 스파이
# 비와 당신의 이야기
# 크루즈 패밀리: 뉴 에이지
# 내가 죽기를 바라는 자들
# 극장판 귀멸의 칼날: 무한열차편
# 미나리
# 내일의 기억
# 분노의 질주: 더 얼티메이트
# 노매드랜드
# 스파이럴
# 명탐정 코난: 비색의 탄환
# 해리 포터와 아즈카반의 죄수
# 보이저스
# 극장판 콩순이: 장난감나라 대모험
# 어른들은 몰라요
# 아이들은 즐겁다
# 자산어보
# 아들의 이름으로
# 학교 가는 길
# 내겐 너무 소중한 너
# 8년을 뛰어넘은 신부
# 키퍼스
# 윈드 리버
# 노바디
# 슈퍼노바
# 서복
# 링: 더 라스트 챕터
# 미스
# 뻐꾸기도 밤에 우는가
# 빅 피쉬
# 낙원의 밤
# 배드 헤어
# 비커밍 아스트리드
# 범털2 : 쩐의 전쟁
# 크루엘라
# 그 시절, 우리가 좋아했던 소녀
# 모탈 컴뱃
# 더 파더
# 소울
# 견: 버려진 아이들
# 레옹
# 화녀
# 잭 스나이더의 저스티스 리그
# 코스믹 씬
# 이터널스
# 그린 북
# 극장판 바다 탐험대 옥토넛 : 불의 고리 대폭발
# 블랙 위도우
# 도라에몽: 스탠바이미 2
# 좋은 빛, 좋은 공기

# %%
#현재상영 영화
import requests
from bs4 import BeautifulSoup

res = requests.get('https://movie.naver.com/movie/running/current.nhn')
soup = BeautifulSoup(res.content, 'html.parser')
data = soup.select('#content > div > div > div > ul > li > dl > dt > a')
for data in data:
   print (data.get_text())
# Out:
# 스파이럴
# 더 스파이
# 내겐 너무 소중한 너
# 극장판 귀멸의 칼날: 무한열차편
# 비와 당신의 이야기
# 크루즈 패밀리: 뉴 에이지
# 노매드랜드
# 아들의 이름으로
# 미나리
# 아이들은 즐겁다
# 빅 피쉬
# 극장판 콩순이: 장난감나라 대모험
# 학교 가는 길
# 명탐정 코난: 비색의 탄환
# 해리 포터와 아즈카반의 죄수
# 아비정전
# 링: 더 라스트 챕터
# 내가 죽기를 바라는 자들
# 체리 향기
# 좋은 빛, 좋은 공기
# 더 파더
# 내 친구의 집은 어디인가
# 비커밍 아스트리드
# 자산어보
# 비밀의 정원
# 바람이 우리를 데려다 주리라
# 그리고 삶은 계속된다
# 내일의 기억
# 슈퍼노바
# 사랑에 빠진 것처럼
# 중경삼림
# 올리브 나무 사이로
# 바람과 함께 사라지다
# 어른들은 몰라요
# 아무도 없는 곳
# 너의 이름은.
# 문라이즈 킹덤
# 키퍼스
# 극장판 바다 탐험대 옥토넛 : 불의 고리 대폭발
# 조제, 호랑이 그리고 물고기들
# 그 시절, 우리가 좋아했던 소녀
# 황무지 5월의 고해
# 좋아해, 너를
# 언어의 정원
# 소년시절의 너
# 화양연화
# 고질라 VS. 콩
# 레이니 데이 인 뉴욕
# 동사서독 리덕스
# 적호서생
# 컴 애즈 유 아
# 불한당: 나쁜 놈들의 세상
# 스파이의 아내
# 별을 쫓는 아이
# 레 미제라블
# 미스
# 오명
# 더스트맨
# 더 박스
# 당신의 사월
# 파리의 별빛 아래
# 열혈남아
# 날씨의 아이
# 구름의 저편, 약속의 장소
# 무순, 세상을 가로질러
# 해길랍
# 레옹
# 피아니스트
# 화녀
# 배드 헤어
# 라야와 마지막 드래곤
# 사랑하고 사랑받고, 차고 차이고
# 더 랍스터
# 소울
# 해피 투게더
# 8년을 뛰어넘은 신부
# 룸
# 섀도우 클라우드
# 세자매
# 코스믹 씬
# 팅커 테일러 솔저 스파이
# 프라미싱 영 우먼
# 그것만이 내 세상
# 내언니전지현과 나
# 다시 태어나도 우리
# 러브 액츄얼리
# 미국대전쟁
# 반지의 제왕: 두 개의 탑
# ...
